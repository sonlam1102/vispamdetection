# %% [markdown]
# ### **Install and import library**

# %%
pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 5.0 MB/s
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.7-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 35.7 MB/s
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.62.3)
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.7 pyvi-0.1.1 sklearn-crfsuite-0.3.6

# %%
from google.colab import drive
import os
import re
import pickle
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from pyvi.ViTokenizer import ViTokenizer
from keras.preprocessing import text, sequence
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Dense, Embedding, Conv2D, MaxPool2D, Bidirectional, LSTM, GRU, concatenate, GlobalMaxPooling1D, GlobalAveragePooling1D, SpatialDropout1D
from keras.layers import Reshape, Flatten, Dropout, Concatenate
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from keras.models import Model
from tensorflow.keras.utils import to_categorical
from keras.preprocessing import text, sequence
from keras import backend as K
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

# %% [markdown]
# ### **Connect to Google Drive**

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
DIR_ROOT = '/gdrive/MyDrive/FakeCommentDetection'
DIR_DATASET = os.path.join(DIR_ROOT, 'dataset')

PATH_TRAIN = os.path.join(DIR_DATASET, 'train.csv')
PATH_DEV = os.path.join(DIR_DATASET, 'dev.csv')
PATH_TEST = os.path.join(DIR_DATASET, 'test.csv')

STOPWORDS_PATH = os.path.join(DIR_ROOT, 'vietnamese-stopwords-dash.txt')
EMBEDDING_PATH = os.path.join(DIR_ROOT, 'cc.vi.300.vec')
TOKENIZER_PATH = os.path.join(DIR_ROOT, 'tokenizer.pickle')

MODEL_DIR = os.path.join(DIR_ROOT, 'model')
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
def show_predict_result(model, X_test, y_test, labels):
    prediction = model.predict(X_test, batch_size=256, verbose=0)
    y_pred = prediction.argmax(axis=-1)
    cf = confusion_matrix(y_test, y_pred)
    df_cm = pd.DataFrame(cf, index = labels , columns = labels)
    sn.heatmap(df_cm, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 30})
    print("F1 - micro:", f1_score(y_test, y_pred, average='micro'))
    print("F1 - macro:", f1_score(y_test, y_pred, average='macro'))
    print("Accuracy:", accuracy_score(y_test, y_pred))

# %% [markdown]
# ### **Load data**

# %%
data_train = pd.read_csv(PATH_TRAIN)
X_train = data_train.iloc[:, 0:2]
y_train = data_train.iloc[:, 2:4]

data_dev = pd.read_csv(PATH_DEV)
X_dev = data_dev.iloc[:, 0:2]
y_dev = data_dev.iloc[:, 2:4]


data_test = pd.read_csv(PATH_TEST)
X_test = data_test.iloc[:, 0:2]
y_test = data_test.iloc[:, 2:4]

# %%
with open(STOPWORDS_PATH, "r") as ins:
    stopwords = []
    for line in ins:
        dd = line.strip('\n')
        stopwords.append(dd)
    stopwords = set(stopwords)

# %%
def filter_stop_words(train_sentences, stop_words):
    new_sent = [word for word in train_sentences.split() if word not in stop_words]
    train_sentences = ' '.join(new_sent)
    return train_sentences


def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)


def preprocess(text, tokenized = True, lowercased = True):
    text = ViTokenizer.tokenize(text) if tokenized else text
    text = filter_stop_words(text, stopwords)
    text = deEmojify(text)
    text = text.lower() if lowercased else text
    return text


def pre_process_features(X, y1, y2, tokenized = True, lowercased = True):
    X = np.array(X)
    y1 = np.array(y1)
    y2 = np.array(y2)
    X = [preprocess(str(p), tokenized = tokenized, lowercased = lowercased) for p in list(X)]
    for idx, ele in enumerate(X):
        if not ele:
            X = np.delete(X, idx)
            y1 = np.delete(y1, idx)
            y2 = np.delete(y2, idx)
    return X, y1, y2


def make_featues(X, y1, y2, tokenizer, is_one_hot_label=True, number_class1=2, number_class2=4):
    X = tokenizer.texts_to_sequences(X)
    X = sequence.pad_sequences(X, maxlen=sequence_length)
    if is_one_hot_label: 
        y1 = to_categorical(y1, num_classes=number_class1)
        y2 = to_categorical(y2, num_classes=number_class2)

    return X, y1, y2

# %%
train_X, train_y, train_y_spam = pre_process_features(X_train['Comment'], y_train['Label'], y_train['SpamLabel'], tokenized=True, lowercased = True)
dev_X, dev_y, dev_y_spam = pre_process_features(X_dev['Comment'], y_dev['Label'], y_dev['SpamLabel'], tokenized=True, lowercased = True)
test_X, test_y, test_y_spam = pre_process_features(X_test['Comment'], y_test['Label'], y_test['SpamLabel'], tokenized=True, lowercased = True)

# %%
embeddings_index = {}
with open(EMBEDDING_PATH, encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %%
tokenizer = text.Tokenizer(lower=False, filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n')
tokenizer.fit_on_texts(train_X)
with open(TOKENIZER_PATH, 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
labels_task_1 = ["no-spam", "spam"]
labels_task_2 = ["no-spam", "spam-1", "spam-2", "spam-3"]

vocabulary_size = 10000
sequence_length = 100

embedding_dim = 300
batch_size = 256
epochs = 40
drop = 0.5

filter_sizes = [2,3,5]
num_filters = 32

word_index = tokenizer.word_index
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue

    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
train_X, train_y, train_y_spam = make_featues(train_X, train_y, train_y_spam, tokenizer)
dev_X, dev_y, dev_y_spam = make_featues(dev_X, dev_y, dev_y_spam, tokenizer)
test_X, test_y, test_y_spam = make_featues(test_X, test_y, test_y_spam, tokenizer, is_one_hot_label=False)

# %% [markdown]
# ### **Text CNN**

# %% [markdown]
# #### **Task 1**

# %%
inputs = Input(shape=(sequence_length,), dtype='int32')
embedding = Embedding(input_dim=num_words, output_dim=embedding_dim, input_length=sequence_length, weights=[embedding_matrix])(inputs)
reshape = Reshape((sequence_length,embedding_dim,1))(embedding)

conv_0 = Conv2D(num_filters, kernel_size=(filter_sizes[0], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)
conv_1 = Conv2D(num_filters, kernel_size=(filter_sizes[1], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)
conv_2 = Conv2D(num_filters, kernel_size=(filter_sizes[2], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)

maxpool_0 = MaxPool1D(3, strides=(1,1), padding='valid')(conv_0)
maxpool_1 = MaxPool1D(3, strides=(1,1), padding='valid')(conv_1)
maxpool_2 = MaxPool1D(3, strides=(1,1), padding='valid')(conv_2)

concatenated_tensor = Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])
flatten = Flatten()(concatenated_tensor)
dropout = Dropout(drop)(flatten)
output = Dense(units=2, activation='softmax')(dropout)

model = Model(inputs=inputs, outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 100, 300)     5031600     input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 100, 300, 1)  0           embedding[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 99, 1, 32)    19232       reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 98, 1, 32)    28832       reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 1, 32)    48032       reshape[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 1, 1, 32)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 1, 1, 32)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 32)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3, 1, 32)     0           max_pooling2d[0][0]
#                                                                  max_pooling2d_1[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 96)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 96)           0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            194         dropout[0][0]
# ==================================================================================================
# Total params: 5,127,890
# Trainable params: 5,127,890
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_X, train_y,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1, 
          validation_data=(dev_X, dev_y))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/40
# 56/56 [==============================] - 60s 448ms/step - loss: 0.6050 - accuracy: 0.7058 - val_loss: 0.5455 - val_accuracy: 0.7288
# Epoch 2/40
# 56/56 [==============================] - 21s 378ms/step - loss: 0.5329 - accuracy: 0.7421 - val_loss: 0.5207 - val_accuracy: 0.7294
# Epoch 3/40
# 56/56 [==============================] - 21s 377ms/step - loss: 0.5100 - accuracy: 0.7621 - val_loss: 0.5067 - val_accuracy: 0.7665
# Epoch 4/40
# 56/56 [==============================] - 21s 375ms/step - loss: 0.4958 - accuracy: 0.7838 - val_loss: 0.4946 - val_accuracy: 0.7722
# 56/56 [==============================] - 21s 377ms/step - loss: 0.2783 - accuracy: 0.8919 - val_loss: 0.3961 - val_accuracy: 0.8301
# Epoch 25/40
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2683 - accuracy: 0.8983 - val_loss: 0.3975 - val_accuracy: 0.8282
# Epoch 26/40
# 56/56 [==============================] - 21s 379ms/step - loss: 0.2582 - accuracy: 0.9021 - val_loss: 0.4001 - val_accuracy: 0.8288
# Epoch 27/40
# 56/56 [==============================] - 21s 377ms/step - loss: 0.2501 - accuracy: 0.9063 - val_loss: 0.4016 - val_accuracy: 0.8307
# Epoch 28/40
# 56/56 [==============================] - 21s 377ms/step - loss: 0.2386 - accuracy: 0.9116 - val_loss: 0.4023 - val_accuracy: 0.8295
# Epoch 29/40
# 56/56 [==============================] - 21s 371ms/step - loss: 0.2305 - accuracy: 0.9147 - val_loss: 0.4059 - val_accuracy: 0.8244
# Epoch 30/40
# 56/56 [==============================] - 21s 378ms/step - loss: 0.2222 - accuracy: 0.9183 - val_loss: 0.4073 - val_accuracy: 0.8276
# Epoch 31/40
# 56/56 [==============================] - 21s 373ms/step - loss: 0.2142 - accuracy: 0.9219 - val_loss: 0.4084 - val_accuracy: 0.8276
# Epoch 32/40
# 56/56 [==============================] - 21s 376ms/step - loss: 0.2050 - accuracy: 0.9284 - val_loss: 0.4165 - val_accuracy: 0.8269
# Epoch 33/40
# 56/56 [==============================] - 21s 381ms/step - loss: 0.1958 - accuracy: 0.9329 - val_loss: 0.4148 - val_accuracy: 0.8250
# Epoch 34/40
# 56/56 [==============================] - 21s 375ms/step - loss: 0.1879 - accuracy: 0.9369 - val_loss: 0.4246 - val_accuracy: 0.8276
# Epoch 35/40
# 56/56 [==============================] - 21s 376ms/step - loss: 0.1810 - accuracy: 0.9367 - val_loss: 0.4224 - val_accuracy: 0.8269
# Epoch 36/40
# 56/56 [==============================] - 21s 375ms/step - loss: 0.1721 - accuracy: 0.9421 - val_loss: 0.4299 - val_accuracy: 0.8263
# Epoch 37/40
# 56/56 [==============================] - 21s 374ms/step - loss: 0.1669 - accuracy: 0.9442 - val_loss: 0.4343 - val_accuracy: 0.8263
# Epoch 38/40
# 56/56 [==============================] - 21s 377ms/step - loss: 0.1611 - accuracy: 0.9468 - val_loss: 0.4364 - val_accuracy: 0.8244
# Epoch 39/40
# 56/56 [==============================] - 21s 376ms/step - loss: 0.1540 - accuracy: 0.9487 - val_loss: 0.4423 - val_accuracy: 0.8250
# Epoch 40/40
# 56/56 [==============================] - 21s 376ms/step - loss: 0.1491 - accuracy: 0.9505 - val_loss: 0.4466 - val_accuracy: 0.8263

# %%
TEXT_CNN_MODEL = os.path.join(MODEL_DIR, 'Text_CNN_task1.h5')
model.save(TEXT_CNN_MODEL, save_format='h5')

# %%
show_predict_result(model, test_X, test_y, labels_task_1)
# Out:
# F1 - micro: 0.8329974811083124
# F1 - macro: 0.7703935361851905
# Accuracy: 0.8329974811083123

# %% [markdown]
# #### **Task 2**

# %%
inputs = Input(shape=(sequence_length,), dtype='int32')
embedding = Embedding(input_dim=num_words, output_dim=embedding_dim, input_length=sequence_length, weights=[embedding_matrix])(inputs)
reshape = Reshape((sequence_length,embedding_dim,1))(embedding)

conv_0 = Conv2D(num_filters, kernel_size=(filter_sizes[0], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)
conv_1 = Conv2D(num_filters, kernel_size=(filter_sizes[1], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)
conv_2 = Conv2D(num_filters, kernel_size=(filter_sizes[2], embedding_dim), padding='valid', kernel_initializer='normal', activation='elu')(reshape)

maxpool_0 = MaxPool2D(pool_size=(sequence_length - filter_sizes[0] + 1, 1), strides=(1,1), padding='valid')(conv_0)
maxpool_1 = MaxPool2D(pool_size=(sequence_length - filter_sizes[1] + 1, 1), strides=(1,1), padding='valid')(conv_1)
maxpool_2 = MaxPool2D(pool_size=(sequence_length - filter_sizes[2] + 1, 1), strides=(1,1), padding='valid')(conv_2)

concatenated_tensor = Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])
flatten = Flatten()(concatenated_tensor)
dropout = Dropout(drop)(flatten)
output = Dense(units=4, activation='softmax')(dropout)

model = Model(inputs=inputs, outputs=output)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 100, 300)     5031600     input_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 100, 300, 1)  0           embedding_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 99, 1, 32)    19232       reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 98, 1, 32)    28832       reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 96, 1, 32)    48032       reshape_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 32)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 32)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 1, 1, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3, 1, 32)     0           max_pooling2d_3[0][0]
#                                                                  max_pooling2d_4[0][0]
#                                                                  max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 96)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 96)           0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            388         dropout_1[0][0]
# ==================================================================================================
# Total params: 5,128,084
# Trainable params: 5,128,084
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_X, train_y_spam,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1, 
          validation_data=(dev_X, dev_y_spam))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/40
# 56/56 [==============================] - 22s 382ms/step - loss: 0.9440 - accuracy: 0.7078 - val_loss: 0.7992 - val_accuracy: 0.7300
# Epoch 2/40
# 56/56 [==============================] - 21s 377ms/step - loss: 0.7740 - accuracy: 0.7438 - val_loss: 0.7405 - val_accuracy: 0.7338
# Epoch 3/40
# 56/56 [==============================] - 21s 378ms/step - loss: 0.7241 - accuracy: 0.7518 - val_loss: 0.7073 - val_accuracy: 0.7382
# Epoch 4/40
# 56/56 [==============================] - 21s 382ms/step - loss: 0.6858 - accuracy: 0.7715 - val_loss: 0.6832 - val_accuracy: 0.7741
# Epoch 5/40
# 56/56 [==============================] - 21s 377ms/step - loss: 0.6610 - accuracy: 0.7899 - val_loss: 0.6641 - val_accuracy: 0.7791
# Epoch 6/40
# 56/56 [==============================] - 21s 380ms/step - loss: 0.6372 - accuracy: 0.7988 - val_loss: 0.6464 - val_accuracy: 0.7816
# Epoch 7/40
# 56/56 [==============================] - 21s 373ms/step - loss: 0.6176 - accuracy: 0.8015 - val_loss: 0.6302 - val_accuracy: 0.7854
# Epoch 8/40
# Epoch 28/40
# 56/56 [==============================] - 21s 376ms/step - loss: 0.3227 - accuracy: 0.8909 - val_loss: 0.4974 - val_accuracy: 0.8175
# Epoch 29/40
# 56/56 [==============================] - 21s 376ms/step - loss: 0.3091 - accuracy: 0.8970 - val_loss: 0.4975 - val_accuracy: 0.8188
# Epoch 30/40
# 56/56 [==============================] - 21s 381ms/step - loss: 0.2986 - accuracy: 0.9009 - val_loss: 0.4972 - val_accuracy: 0.8200
# Epoch 31/40
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2883 - accuracy: 0.9026 - val_loss: 0.4980 - val_accuracy: 0.8181
# Epoch 32/40
# 56/56 [==============================] - 21s 378ms/step - loss: 0.2778 - accuracy: 0.9073 - val_loss: 0.4989 - val_accuracy: 0.8200
# Epoch 33/40
# 56/56 [==============================] - 21s 381ms/step - loss: 0.2692 - accuracy: 0.9115 - val_loss: 0.5010 - val_accuracy: 0.8200
# Epoch 34/40
# 56/56 [==============================] - 21s 381ms/step - loss: 0.2559 - accuracy: 0.9151 - val_loss: 0.5013 - val_accuracy: 0.8225
# Epoch 35/40
# 56/56 [==============================] - 21s 380ms/step - loss: 0.2505 - accuracy: 0.9192 - val_loss: 0.5010 - val_accuracy: 0.8244
# Epoch 36/40
# 56/56 [==============================] - 21s 378ms/step - loss: 0.2417 - accuracy: 0.9236 - val_loss: 0.5062 - val_accuracy: 0.8232
# Epoch 37/40
# 56/56 [==============================] - 21s 378ms/step - loss: 0.2339 - accuracy: 0.9252 - val_loss: 0.5042 - val_accuracy: 0.8250
# Epoch 38/40
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2254 - accuracy: 0.9287 - val_loss: 0.5093 - val_accuracy: 0.8213
# Epoch 39/40
# 56/56 [==============================] - 22s 390ms/step - loss: 0.2197 - accuracy: 0.9301 - val_loss: 0.5086 - val_accuracy: 0.8238
# Epoch 40/40
# 56/56 [==============================] - 21s 380ms/step - loss: 0.2106 - accuracy: 0.9325 - val_loss: 0.5117 - val_accuracy: 0.8232

# %%
TEXT_CNN_MODEL = os.path.join(MODEL_DIR, 'Text_CNN_task2.h5')
model.save(TEXT_CNN_MODEL, save_format='h5')

# %%
show_predict_result(model, test_X, test_y_spam, labels_task_2)
# Out:
# F1 - micro: 0.830478589420655
# F1 - macro: 0.6414031582899572
# Accuracy: 0.8304785894206549

# %% [markdown]
# ### **BiLSTM**

# %% [markdown]
# #### **Task 1**

# %%
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
x = SpatialDropout1D(0.2)(x)
x = Bidirectional(LSTM(64, return_sequences=True))(x)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
output = Dense(2, activation="softmax")(conc)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 100, 300)     5031600     input_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 100, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 100, 128)     186880      spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 128)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256)          0           global_average_pooling1d[0][0]
#                                                                  global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            514         concatenate_2[0][0]
# ==================================================================================================
# Total params: 5,218,994
# Trainable params: 5,218,994
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_X, train_y,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1, 
          validation_data=(dev_X, dev_y))
# Out:
# Epoch 1/40
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 56/56 [==============================] - 10s 86ms/step - loss: 0.6670 - accuracy: 0.6362 - val_loss: 0.6187 - val_accuracy: 0.7281
# Epoch 2/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.5660 - accuracy: 0.7401 - val_loss: 0.5496 - val_accuracy: 0.7281
# Epoch 3/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.5256 - accuracy: 0.7403 - val_loss: 0.5219 - val_accuracy: 0.7294
# Epoch 4/40
# 56/56 [==============================] - 4s 68ms/step - loss: 0.4937 - accuracy: 0.7491 - val_loss: 0.4887 - val_accuracy: 0.7520
# Epoch 5/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.4556 - accuracy: 0.8008 - val_loss: 0.4594 - val_accuracy: 0.8043
# Epoch 6/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.4291 - accuracy: 0.8288 - val_loss: 0.4462 - val_accuracy: 0.7942
# Epoch 7/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.4029 - accuracy: 0.8396 - val_loss: 0.4367 - val_accuracy: 0.8143
# Epoch 8/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.3840 - accuracy: 0.8418 - val_loss: 0.4550 - val_accuracy: 0.8188
# Epoch 9/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.3665 - accuracy: 0.8555 - val_loss: 0.4253 - val_accuracy: 0.8225
# Epoch 10/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.3468 - accuracy: 0.8676 - val_loss: 0.4240 - val_accuracy: 0.8194
# Epoch 11/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.3346 - accuracy: 0.8744 - val_loss: 0.4197 - val_accuracy: 0.8232
# Epoch 12/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.3126 - accuracy: 0.8819 - val_loss: 0.4301 - val_accuracy: 0.8213
# Epoch 13/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2977 - accuracy: 0.8891 - val_loss: 0.4168 - val_accuracy: 0.8225
# Epoch 14/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2840 - accuracy: 0.8916 - val_loss: 0.4361 - val_accuracy: 0.8143
# Epoch 15/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2700 - accuracy: 0.8987 - val_loss: 0.4428 - val_accuracy: 0.8188
# Epoch 16/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2604 - accuracy: 0.9008 - val_loss: 0.4291 - val_accuracy: 0.8175
# Epoch 17/40
# Epoch 37/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.1500 - accuracy: 0.9439 - val_loss: 0.6037 - val_accuracy: 0.8074
# Epoch 38/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.1475 - accuracy: 0.9467 - val_loss: 0.5588 - val_accuracy: 0.8118
# Epoch 39/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.1467 - accuracy: 0.9465 - val_loss: 0.5600 - val_accuracy: 0.8118
# Epoch 40/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.1409 - accuracy: 0.9494 - val_loss: 0.5864 - val_accuracy: 0.8030

# %%
BILSTM_MODEL = os.path.join(MODEL_DIR, 'BiLSTM_task1.h5')
model.save(BILSTM_MODEL, save_format='h5')

# %%
show_predict_result(model, test_X, test_y, labels_task_1)
# Out:
# F1 - micro: 0.8120906801007556
# F1 - macro: 0.7497062347201489
# Accuracy: 0.8120906801007557

# %% [markdown]
# #### **Task 2**

# %%
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
x = SpatialDropout1D(0.2)(x)
x = Bidirectional(LSTM(64, return_sequences=True))(x)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
output = Dense(4, activation="softmax")(conc)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 100, 300)     5031600     input_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 100, 300)     0           embedding_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 100, 128)     186880      spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256)          0           global_average_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            1028        concatenate_3[0][0]
# ==================================================================================================
# Total params: 5,219,508
# Trainable params: 5,219,508
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_X, train_y_spam,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1, 
          validation_data=(dev_X, dev_y_spam))
# Out:
# Epoch 1/40
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 56/56 [==============================] - 9s 92ms/step - loss: 1.2470 - accuracy: 0.6656 - val_loss: 1.0812 - val_accuracy: 0.7281
# Epoch 2/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.8768 - accuracy: 0.7400 - val_loss: 0.7843 - val_accuracy: 0.7281
# Epoch 3/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.7383 - accuracy: 0.7401 - val_loss: 0.7446 - val_accuracy: 0.7281
# Epoch 4/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.7039 - accuracy: 0.7404 - val_loss: 0.7148 - val_accuracy: 0.7294
# Epoch 5/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.6709 - accuracy: 0.7481 - val_loss: 0.6844 - val_accuracy: 0.7451
# Epoch 6/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.6396 - accuracy: 0.7850 - val_loss: 0.6571 - val_accuracy: 0.7892
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2560 - accuracy: 0.9159 - val_loss: 0.6150 - val_accuracy: 0.8137
# Epoch 27/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2508 - accuracy: 0.9160 - val_loss: 0.6291 - val_accuracy: 0.7992
# Epoch 28/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2491 - accuracy: 0.9186 - val_loss: 0.6289 - val_accuracy: 0.8018
# Epoch 29/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2384 - accuracy: 0.9208 - val_loss: 0.6268 - val_accuracy: 0.8005
# Epoch 30/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2307 - accuracy: 0.9235 - val_loss: 0.6345 - val_accuracy: 0.7974
# Epoch 31/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2240 - accuracy: 0.9261 - val_loss: 0.6488 - val_accuracy: 0.7948
# Epoch 32/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2187 - accuracy: 0.9273 - val_loss: 0.6502 - val_accuracy: 0.7992
# Epoch 33/40
# 56/56 [==============================] - 4s 68ms/step - loss: 0.2175 - accuracy: 0.9267 - val_loss: 0.6417 - val_accuracy: 0.7923
# Epoch 34/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2369 - accuracy: 0.9217 - val_loss: 0.6236 - val_accuracy: 0.7917
# Epoch 35/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2183 - accuracy: 0.9264 - val_loss: 0.6448 - val_accuracy: 0.8024
# Epoch 36/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.2051 - accuracy: 0.9305 - val_loss: 0.6702 - val_accuracy: 0.8011
# Epoch 37/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.2050 - accuracy: 0.9305 - val_loss: 0.6605 - val_accuracy: 0.7955
# Epoch 38/40
# 56/56 [==============================] - 4s 69ms/step - loss: 0.1899 - accuracy: 0.9369 - val_loss: 0.6605 - val_accuracy: 0.8037
# Epoch 39/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.1900 - accuracy: 0.9366 - val_loss: 0.6782 - val_accuracy: 0.7974
# Epoch 40/40
# 56/56 [==============================] - 4s 70ms/step - loss: 0.1850 - accuracy: 0.9385 - val_loss: 0.6837 - val_accuracy: 0.8068

# %%
BILSTM_MODEL = os.path.join(MODEL_DIR, 'BiLSTM_task2.h5')
model.save(BILSTM_MODEL, save_format='h5')

# %%
show_predict_result(model, test_X, test_y_spam, labels_task_2)
# Out:
# F1 - micro: 0.8083123425692695
# F1 - macro: 0.5819454865563078
# Accuracy: 0.8083123425692695

# %% [markdown]
# ### **GRU**

# %% [markdown]
# #### **Task 1**

# %%
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
x = SpatialDropout1D(0.2)(x)
x = Bidirectional(GRU(80, return_sequences=True))(x)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
output = Dense(2, activation="softmax")(conc)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 100, 300)     5031600     input_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 100, 300)     0           embedding_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 100, 160)     183360      spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 160)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 160)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 320)          0           global_average_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            642         concatenate_4[0][0]
# ==================================================================================================
# Total params: 5,215,602
# Trainable params: 5,215,602
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_X, train_y,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(dev_X, dev_y))
# Out:
# Epoch 1/40
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 56/56 [==============================] - 9s 88ms/step - loss: 0.6462 - accuracy: 0.6861 - val_loss: 0.5968 - val_accuracy: 0.7281
# Epoch 2/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.5582 - accuracy: 0.7400 - val_loss: 0.5453 - val_accuracy: 0.7281
# Epoch 3/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.5225 - accuracy: 0.7401 - val_loss: 0.5253 - val_accuracy: 0.7281
# Epoch 4/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.5005 - accuracy: 0.7429 - val_loss: 0.5002 - val_accuracy: 0.7382
# Epoch 5/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.4760 - accuracy: 0.7761 - val_loss: 0.4787 - val_accuracy: 0.7879
# Epoch 6/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.4526 - accuracy: 0.8107 - val_loss: 0.4604 - val_accuracy: 0.7999
# Epoch 7/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.4290 - accuracy: 0.8229 - val_loss: 0.4455 - val_accuracy: 0.8137
# Epoch 8/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.4051 - accuracy: 0.8380 - val_loss: 0.4330 - val_accuracy: 0.8143
# Epoch 9/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.3802 - accuracy: 0.8494 - val_loss: 0.4227 - val_accuracy: 0.8250
# Epoch 10/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.3536 - accuracy: 0.8594 - val_loss: 0.4199 - val_accuracy: 0.8232
# Epoch 11/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.3250 - accuracy: 0.8689 - val_loss: 0.4194 - val_accuracy: 0.8269
# Epoch 12/40
# 56/56 [==============================] - 4s 74ms/step - loss: 0.3017 - accuracy: 0.8813 - val_loss: 0.4139 - val_accuracy: 0.8263
# Epoch 13/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.2836 - accuracy: 0.8899 - val_loss: 0.4248 - val_accuracy: 0.8225
# Epoch 14/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2680 - accuracy: 0.8954 - val_loss: 0.4254 - val_accuracy: 0.8188
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1326 - accuracy: 0.9532 - val_loss: 0.6551 - val_accuracy: 0.8118
# Epoch 35/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1330 - accuracy: 0.9519 - val_loss: 0.6211 - val_accuracy: 0.8118
# Epoch 36/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.1296 - accuracy: 0.9525 - val_loss: 0.6107 - val_accuracy: 0.8143
# Epoch 37/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1282 - accuracy: 0.9535 - val_loss: 0.6029 - val_accuracy: 0.8087
# Epoch 38/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1278 - accuracy: 0.9528 - val_loss: 0.6350 - val_accuracy: 0.8118
# Epoch 39/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.1219 - accuracy: 0.9554 - val_loss: 0.6256 - val_accuracy: 0.8131
# Epoch 40/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.1209 - accuracy: 0.9565 - val_loss: 0.6274 - val_accuracy: 0.8055

# %%
GRU_MODEL = os.path.join(MODEL_DIR, 'GRU_task1.h5')
model.save(GRU_MODEL, save_format='h5')

# %%
show_predict_result(model, test_X, test_y, labels_task_1)
# Out:
# F1 - micro: 0.8173803526448362
# F1 - macro: 0.758442429737233
# Accuracy: 0.8173803526448362

# %% [markdown]
# #### **Task 2**

# %%
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
x = SpatialDropout1D(0.2)(x)
x = Bidirectional(GRU(80, return_sequences=True))(x)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
output = Dense(4, activation="softmax")(conc)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 100, 300)     5031600     input_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 100, 300)     0           embedding_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 100, 160)     183360      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 160)          0           bidirectional_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 160)          0           bidirectional_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 320)          0           global_average_pooling1d_5[0][0]
#                                                                  global_max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 4)            1284        concatenate_7[0][0]
# ==================================================================================================
# Total params: 5,216,244
# Trainable params: 5,216,244
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_X, train_y_spam,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(dev_X, dev_y_spam))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/40
# 56/56 [==============================] - 8s 88ms/step - loss: 1.1223 - accuracy: 0.7340 - val_loss: 0.9570 - val_accuracy: 0.7281
# Epoch 2/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.8315 - accuracy: 0.7400 - val_loss: 0.7755 - val_accuracy: 0.7281
# Epoch 3/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.7261 - accuracy: 0.7400 - val_loss: 0.7262 - val_accuracy: 0.7281
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2766 - accuracy: 0.9054 - val_loss: 0.5633 - val_accuracy: 0.8188
# Epoch 24/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2613 - accuracy: 0.9129 - val_loss: 0.5777 - val_accuracy: 0.8162
# Epoch 25/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2521 - accuracy: 0.9133 - val_loss: 0.5759 - val_accuracy: 0.8188
# Epoch 26/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2414 - accuracy: 0.9202 - val_loss: 0.5915 - val_accuracy: 0.8175
# Epoch 27/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2332 - accuracy: 0.9221 - val_loss: 0.5882 - val_accuracy: 0.8169
# Epoch 28/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2272 - accuracy: 0.9245 - val_loss: 0.5919 - val_accuracy: 0.8175
# Epoch 29/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.2204 - accuracy: 0.9262 - val_loss: 0.6246 - val_accuracy: 0.8169
# Epoch 30/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2092 - accuracy: 0.9310 - val_loss: 0.6121 - val_accuracy: 0.8194
# Epoch 31/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.2062 - accuracy: 0.9306 - val_loss: 0.6397 - val_accuracy: 0.8099
# Epoch 32/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.1957 - accuracy: 0.9362 - val_loss: 0.6577 - val_accuracy: 0.8118
# Epoch 33/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1937 - accuracy: 0.9364 - val_loss: 0.6105 - val_accuracy: 0.8162
# Epoch 34/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1890 - accuracy: 0.9383 - val_loss: 0.6450 - val_accuracy: 0.8118
# Epoch 35/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1844 - accuracy: 0.9389 - val_loss: 0.6868 - val_accuracy: 0.8093
# Epoch 36/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1771 - accuracy: 0.9412 - val_loss: 0.6719 - val_accuracy: 0.8150
# Epoch 37/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.1746 - accuracy: 0.9411 - val_loss: 0.6541 - val_accuracy: 0.8106
# Epoch 38/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1697 - accuracy: 0.9431 - val_loss: 0.6244 - val_accuracy: 0.8118
# Epoch 39/40
# 56/56 [==============================] - 4s 72ms/step - loss: 0.1669 - accuracy: 0.9454 - val_loss: 0.7138 - val_accuracy: 0.8118
# Epoch 40/40
# 56/56 [==============================] - 4s 73ms/step - loss: 0.1621 - accuracy: 0.9462 - val_loss: 0.6476 - val_accuracy: 0.8106

# %%
GRU_MODEL = os.path.join(MODEL_DIR, 'GRU_task2.h5')
model.save(GRU_MODEL, save_format='h5')

# %%
show_predict_result(model, test_X, test_y_spam, labels_task_2)
# Out:
# F1 - micro: 0.8183879093198992
# F1 - macro: 0.641403791637932
# Accuracy: 0.8183879093198992
